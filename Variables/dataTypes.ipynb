# %%
age = 19
print(age)
print("this is integer type data ")
type(age)
# Out:
# 19
# this is integer type data
# int

# %%
grades = 3.5
print(grades)
print("this is a float type data type")
type(grades)
# Out:
# 3.5
# this is a float type data type
# float

# %%
name = "Ali"
print(name)
type(name)
# Out:
# Ali
# str

# %%
print(name+" is a student")
# Out:
# Ali is a student

# %%
result_print=True
print(result_print)
type(result_print)
# Out:
# True
# bool
