# %%
with open("Demo1.txt","r") as file:
    data = file.read()
    print(data)
#File will be closed automatically
# Out:
# Python is used in AI
#  and it is also used in Data Science
# Python is mostly used in this fields Because of its varieties in libraries

# %%
#tempfile.TemporaryFile is used to create a temporary file which will be delected automatically
#zipfile.ZipFile is used to open a zip file 
#pathlib.path().open() is used to open object oriented file via pathlib
