# %%
file = open("demo1.txt","r")

# %%
print(file.read())
# Out:
# Python is a great language which is mostly used in Artificial Intelligence and Data Science due to its great number of libraries
# It is easy to learn

# %%
file.close()

# %%
file = open("demo1.txt","w")

# %%
file.write("Python is also used in other fields too")
# Out:
# 39

# %%
file.close()

# %%
file = open("demo1.txt","r")

# %%
print(file.read())
# Out:
# Python is also used in other fields too

# %%
file.close()
