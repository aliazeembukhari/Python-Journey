# %%
import numpy as np

# %%
arr = np.array([1,2,3])
print(arr)
# Out:
# [1 2 3]

# %%
print(np.zeros((3,3)))
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [0. 0. 0.]]

# %%
print(np.ones((3,3)))
# Out:
# [[1. 1. 1.]
#  [1. 1. 1.]
#  [1. 1. 1.]]

# %%
print(np.full((3,3),4))
# Out:
# [[4 4 4]
#  [4 4 4]
#  [4 4 4]]

# %%
print(np.arange(0,16,4)) #print 0 to 15 with the gap of 4
# Out:
# [ 0  4  8 12]
