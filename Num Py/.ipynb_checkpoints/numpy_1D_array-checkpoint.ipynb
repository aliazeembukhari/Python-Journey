# %%
import numpy as np

# %%
arr = np.array([1,2,3])
print(arr)
# Out:
# [1 2 3]

# %%
print(np.zeros((3,3)))
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [0. 0. 0.]]

# %%
print(np.ones((3,3)))
# Out:
# [[1. 1. 1.]
#  [1. 1. 1.]
#  [1. 1. 1.]]

# %%
print(np.full((3,3),4))
# Out:
# [[4 4 4]
#  [4 4 4]
#  [4 4 4]]

# %%
print(np.arange(0,16,4)) #print 0 to 15 with the gap of 4
# Out:
# [ 0  4  8 12]

# %%
print(np.linspace(0,1,5)) #split in 5 equal parts
# Out:
# [0.   0.25 0.5  0.75 1.  ]

# %%
print(np.eye(3)) #it will print the identity matrix (all diaognal will be 1)
# Out:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %%
print(np.diag([1,2,6]))
# Out:
# [[1 0 0]
#  [0 2 0]
#  [0 0 6]]

# %%
np.array([1,5,6],dtype=float)
# Out:
# array([1., 5., 6.])

# %%
arr = np.array([5.3,7.9,9.1])
print(arr.astype(int))
# Out:
# [5 7 9]
