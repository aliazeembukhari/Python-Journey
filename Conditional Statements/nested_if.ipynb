# %%
age = int(input("Enter Your age: "))
country = "Pakistan"
if age>= 18:
    if country == "Pakistan":
        print("You are Eligible for voting")
else:
    print("You are not eligible")
# Out:
# Enter Your age:  12
# You are not eligible

# %% [markdown]
# **Combine condition**

# %%
age1 = int(input("Enter Your age: "))
if age1>=18 and country == "Pakistan":
    print("You are Eligible for voting")
else:
    print("You are not eligible")
# Out:
# Enter Your age:  19
# You are Eligible for voting
