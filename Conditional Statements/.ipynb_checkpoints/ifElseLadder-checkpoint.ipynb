# %%
grades = int(input("Enter yours grades out of 100: "))
if grades>=90:
    print("A+")
elif grades>=80:
    print("A")
elif grades>=70:
    print("B+")
else:
    print("below average")
# Out:
# Enter yours grades out of 100:  98
# A+
