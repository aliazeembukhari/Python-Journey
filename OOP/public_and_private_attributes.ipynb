# %%
class Student:
    def __init__(self,name,grade):
        self.__grade = grade #private attribute

student1 = Student("ali",13)
print(student1.__grade) #it will generate error
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 6
#       3         self.__grade = grade #private attribute
#       5 student1 = Student("ali",13)
# ----> 6 print(student1.__grade) #it will generate error
#
# AttributeError: 'Student' object has no attribute '__grade'

# %%
class Student:
    def __init__(self,name,grade):
        self.__grade = grade #private attribute

student1 = Student("ali",13)
print(student1.__grade) #it will generate error
