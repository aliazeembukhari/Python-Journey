# %%
class Animal:
    def bark(self):
        print("Dog Barking")
    def roar(self):
        print("Lion Roaring")

# %%
class Dog(Animal):
    pass

# %%
dog1 = Dog()

# %%
dog1.bark()
# Out:
# Dog Barking

# %%
class Dog(Animal):
    def pet(self):
        print("My dog name i")
# Out:
#   Cell In[11], line 2
#     def pet(self):
#                   ^
# _IncompleteInputError: incomplete input
