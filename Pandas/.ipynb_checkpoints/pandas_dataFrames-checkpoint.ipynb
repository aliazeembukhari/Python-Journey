# %%
import pandas as pd

# %%
data = {
    "Name:":["Ali","Azeem","Bukhari"],
    "Age":[18,19,20],
    "City":["Multan","Bwp","Vehari"]
}
df = pd.DataFrame(data)
print(df)
# Out:
#      Name:  Age    City
# 0      Ali   18  Multan
# 1    Azeem   19     Bwp
# 2  Bukhari   20  Vehari

# %%
#loading sample csv file
df = pd.read_csv("randomFile.csv")

#Inspect DataFrame
print("Info\n",df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Index              100 non-null    int64
#  1   Customer Id        100 non-null    object
#  2   First Name         100 non-null    object
#  3   Last Name          100 non-null    object
#  4   Company            100 non-null    object
#  5   City               100 non-null    object
#  6   Country            100 non-null    object
#  7   Phone 1            100 non-null    object
#  8   Phone 2            100 non-null    object
#  9   Email              100 non-null    object
#  10  Subscription Date  100 non-null    object
#  11  Website            100 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 9.5+ KB
# Info
#  None

# %%
print("\nShapes:",df.shape) #it will tell the no of rows and columns
print("\nDataType:",df.dtypes)
# Out:
# Shapes: (100, 12)
#
# DataType: Index                 int64
# Customer Id          object
# First Name           object
# Last Name            object
# Company              object
# City                 object
# Country              object
# Phone 1              object
# Phone 2              object
# Email                object
# Subscription Date    object
# Website              object
# dtype: object

# %%
print("\nStatictical Summary:",df.describe())
# Out:
# Statictical Summary:             Index
# count  100.000000
# mean    50.500000
# std     29.011492
# min      1.000000
# 25%     25.750000
# 50%     50.500000
# 75%     75.250000
# max    100.000000
