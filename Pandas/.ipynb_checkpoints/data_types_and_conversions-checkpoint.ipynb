# %%
import pandas as pd

# %%
df = pd.read_csv("randomFile.csv",
                parse_dates = ['Subscription Date'],
                dtype={
                    'Email': 'email'
                })
df.info()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df = pd.read_csv("randomFile.csv",
#       2                 parse_dates = ['Subscription Date'],
#       3                 dtype={
#       4                     'Email': 'email'
#       5                 })
#       6 df.info()
#
# ...
