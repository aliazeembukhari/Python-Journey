# %%
for i in range(3):
    print("Outer Loop")
    for j in range(3):
        print("    Inner Loop")
# Out:
# Outer Loop
#     Inner Loop
#     Inner Loop
#     Inner Loop
# Outer Loop
#     Inner Loop
#     Inner Loop
#     Inner Loop
# Outer Loop
#     Inner Loop
#     Inner Loop
#     Inner Loop
