# %%
varAdd = lambda a,b: a+b

# %%
print(varAdd(23,45))
# Out:
# 68

# %%
no = [ 2,4,6,7 ]

# %%
square = list(map(lambda x:x*x, no))
print(square)
# Out:
# [4, 16, 36, 49]

# %%
numbers = [1,2,3,4,5,7,9]
odd_numbers = list(filter(lambda x: x%2 != 0, numbers))

# %%
print(odd_numbers)
# Out:
# [1, 3, 5, 7, 9]

# %%
even_numbers = list(filter(lambda x:x%2 == 0, numbers))
print(even_numbers)
# Out:
# [2, 4]
