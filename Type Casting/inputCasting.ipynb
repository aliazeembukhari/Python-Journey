# %%
age = input("Enter your age:")
# Out:
# Enter your age: 19

# %%
print(age)
type(age)
# Out:
# 19
# str

# %%
intAge = int(age)
type(intAge)
# Out:
# int

# %%
age2 = int(input("Enter your age:"))
# Out:
# Enter your age: 19

# %%
type(age2)
# Out:
# int
